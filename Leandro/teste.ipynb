# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import matplotlib
matplotlib.rcParams['figure.figsize'] = (16, 8)

from alpha_vantage.timeseries import TimeSeries

# %%
# Chave de acesso a API AlphaVantage
ALPHAVANTAGE_API_KEY = "J1I1A3WWLT6M94UH"

# %%
ts = TimeSeries(key=ALPHAVANTAGE_API_KEY, output_format='pandas')
ts.get_symbol_search('bovespa')
# Out:
# (           1. symbol                          2. name 3. type  \
#  date
#  1970-01-01  INDX.SAO  BOVESPA INDUSTRIAL SECTOR INDEX  Equity
#
#                     4. region 5. marketOpen 6. marketClose 7. timezone  \
#  date
#  1970-01-01  Brazil/Sao Paolo         10:00          17:30      UTC-03
#
#             8. currency 9. matchScore
#  date
#  1970-01-01         BRL        0.3684  ,
#  None)

# %%
dados, meta_dados = ts.get_daily(symbol='B3SA3.SAO', outputsize='full')
dados

# INDX.SAO -> código do bovespa
# Out:
#             1. open  2. high  3. low  4. close    5. volume
# date
# 2024-04-05    12.13    12.20   11.91     12.00   45631500.0
# 2024-04-04    11.99    12.24   11.91     11.96   72579200.0
# 2024-04-03    11.76    11.78   11.51     11.70   61062600.0
# 2024-04-02    11.82    11.85   11.62     11.73   61624700.0
# 2024-04-01    12.06    12.11   11.73     11.77   48653200.0
# ...             ...      ...     ...       ...          ...
# 2007-12-06    23.55    23.77   22.70     23.25   24118825.0
# 2007-12-05    23.42    23.87   23.15     23.59   20468421.0
# 2007-12-04    23.10    23.30   22.15     23.10   27755429.0
# 2007-12-03    24.00    24.35   23.50     23.50   42726945.0
# 2007-11-30    25.00    26.00   24.10     24.40  311678434.0
#
# [4046 rows x 5 columns]

# %%
meta_dados
# Out:
# {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#  '2. Symbol': 'B3SA3.SAO',
#  '3. Last Refreshed': '2024-04-05',
#  '4. Output Size': 'Full size',
#  '5. Time Zone': 'US/Eastern'}

# %%
dados['4. close'].plot()
# Out:
# <Axes: xlabel='date'>
